# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Lab: Exploratory Data Analysis**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will work with a cleaned dataset to perform Exploratory Data Analysis or EDA.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# - Examine the structure of a dataset.
#
# - Handle missing values effectively.
#
# - Conduct summary statistics on key columns.
#
# - Analyze employment status, job satisfaction, programming language usage, and trends in remote work.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# #### Step 1: Install and Import Libraries

# %% [markdown]
# Install the necessary libraries for data manipulation and visualization.

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.2.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.2)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 191.8 MB/s eta 0:00:00
# Downloading numpy-2.2.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 203.2 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-2.2.4 pandas-2.2.3 tzdata-2025.2
# Collecting matplotlib
#   Downloading matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.57.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (102 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 174.4 MB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.57.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 143.1 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 111.8 MB/s eta 0:00:00
# Downloading pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 164.0 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.57.0 kiwisolver-1.4.8 matplotlib-3.10.1 pillow-11.2.1 pyparsing-3.2.3
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/conda/lib/python3.12/site-packages (from seaborn) (2.2.4)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/conda/lib/python3.12/site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %% [markdown]
# #### Step 2: Load and Preview the Dataset
# Load the dataset from the provided URL. Use df.head() to display the first few rows to get an overview of the structure.

# %%
# Load the Stack Overflow survey dataset
data_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv'
df = pd.read_csv(data_url)

# Set pandas option to display all columns
pd.set_option('display.max_columns', None)

# Display the first few rows of the dataset
df.head(2)
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
#
#                                         EdLevel  \
# 0                     Primary/elementary school
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
#
#                                      LearnCodeOnline  \
# 0                                                NaN
# 1  Technical documentation;Blogs;Books;Written Tu...
#
#                                              TechDoc YearsCode YearsCodePro  \
# 0                                                NaN       NaN          NaN
# 1  API document(s) and/or SDK document(s);User gu...        20           17
#
#                  DevType OrgSize PurchaseInfluence BuyNewTool BuildvsBuy  \
# 0                    NaN     NaN               NaN        NaN        NaN
# 1  Developer, full-stack     NaN               NaN        NaN        NaN
#
#   TechEndorse                                            Country Currency  \
# 0         NaN                           United States of America      NaN
# 1         NaN  United Kingdom of Great Britain and Northern I...      NaN
#
#    CompTotal                             LanguageHaveWorkedWith  \
# 0        NaN                                                NaN
# 1        NaN  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
#
#                               LanguageWantToWorkWith  \
# 0                                                NaN
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
#
#                                      LanguageAdmired  \
# 0                                                NaN
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
#
#         DatabaseHaveWorkedWith DatabaseWantToWorkWith DatabaseAdmired  \
# 0                          NaN                    NaN             NaN
# 1  Dynamodb;MongoDB;PostgreSQL             PostgreSQL      PostgreSQL
#
#                      PlatformHaveWorkedWith  \
# 0                                       NaN
# 1  Amazon Web Services (AWS);Heroku;Netlify
#
#                      PlatformWantToWorkWith  \
# 0                                       NaN
# 1  Amazon Web Services (AWS);Heroku;Netlify
#
#                             PlatformAdmired         WebframeHaveWorkedWith  \
# 0                                       NaN                            NaN
# 1  Amazon Web Services (AWS);Heroku;Netlify  Express;Next.js;Node.js;React
#
#              WebframeWantToWorkWith        WebframeAdmired  \
# 0                               NaN                    NaN
# 1  Express;Htmx;Node.js;React;Remix  Express;Node.js;React
#
#   EmbeddedHaveWorkedWith EmbeddedWantToWorkWith EmbeddedAdmired  \
# 0                    NaN                    NaN             NaN
# 1                    NaN                    NaN             NaN
#
#   MiscTechHaveWorkedWith MiscTechWantToWorkWith MiscTechAdmired  \
# 0                    NaN                    NaN             NaN
# 1                    NaN                    NaN             NaN
#
#                        ToolsTechHaveWorkedWith  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
#
#                        ToolsTechWantToWorkWith  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
#
#                               ToolsTechAdmired  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
#
#           NEWCollabToolsHaveWorkedWith         NEWCollabToolsWantToWorkWith  \
# 0                                  NaN                                  NaN
# 1  PyCharm;Visual Studio Code;WebStorm  PyCharm;Visual Studio Code;WebStorm
#
#                  NEWCollabToolsAdmired OpSysPersonal use  \
# 0                                  NaN               NaN
# 1  PyCharm;Visual Studio Code;WebStorm     MacOS;Windows
#
#   OpSysProfessional use OfficeStackAsyncHaveWorkedWith  \
# 0                   NaN                            NaN
# 1                 MacOS                            NaN
#
#   OfficeStackAsyncWantToWorkWith OfficeStackAsyncAdmired  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
#
#   OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# 0                           NaN                           NaN
# 1         Microsoft Teams;Slack                         Slack
#
#   OfficeStackSyncAdmired AISearchDevHaveWorkedWith AISearchDevWantToWorkWith  \
# 0                    NaN                       NaN                       NaN
# 1                  Slack                       NaN                       NaN
#
#   AISearchDevAdmired                                         NEWSOSites  \
# 0                NaN  I have never visited Stack Overflow or the Sta...
# 1                NaN  Stack Overflow for Teams (private knowledge sh...
#
#               SOVisitFreq SOAccount              SOPartFreq  \
# 0                     NaN       NaN                     NaN
# 1  Multiple times per day       Yes  Multiple times per day
#
#                                                SOHow           SOComm  \
# 0                                                NaN              NaN
# 1  Quickly finding code solutions;Finding reliabl...  Yes, definitely
#
#                   AISelect          AISent                  AIBen AIAcc  \
# 0                      Yes  Very favorable  Increase productivity   NaN
# 1  No, and I don't plan to             NaN                    NaN   NaN
#
#   AIComplex AIToolCurrently Using AIToolInterested in Using  \
# 0       NaN                   NaN                       NaN
# 1       NaN                   NaN                       NaN
#
#   AIToolNot interested in Using AINextMuch more integrated AINextNo change  \
# 0                           NaN                        NaN             NaN
# 1                           NaN                        NaN             NaN
#
#   AINextMore integrated AINextLess integrated AINextMuch less integrated  \
# 0                   NaN                   NaN                        NaN
# 1                   NaN                   NaN                        NaN
#
#   AIThreat AIEthics AIChallenges TBranch                  ICorPM  WorkExp  \
# 0      NaN      NaN          NaN      No                     NaN      NaN
# 1      NaN      NaN          NaN     Yes  Individual contributor     17.0
#
#   Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4 Knowledge_5  \
# 0         NaN         NaN         NaN         NaN         NaN
# 1       Agree    Disagree       Agree       Agree       Agree
#
#                   Knowledge_6 Knowledge_7 Knowledge_8 Knowledge_9 Frequency_1  \
# 0                         NaN         NaN         NaN         NaN         NaN
# 1  Neither agree nor disagree    Disagree       Agree       Agree         NaN
#
#   Frequency_2 Frequency_3 TimeSearching TimeAnswering Frustration  \
# 0         NaN         NaN           NaN           NaN         NaN
# 1         NaN         NaN           NaN           NaN         NaN
#
#   ProfessionalTech ProfessionalCloud ProfessionalQuestion Industry  \
# 0              NaN               NaN                  NaN      NaN
# 1              NaN               NaN                  NaN      NaN
#
#    JobSatPoints_1  JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  \
# 0             NaN             NaN             NaN             NaN
# 1             0.0             0.0             0.0             0.0
#
#    JobSatPoints_7  JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  \
# 0             NaN             NaN             NaN              NaN
# 1             0.0             0.0             0.0              0.0
#
#    JobSatPoints_11 SurveyLength SurveyEase  ConvertedCompYearly  JobSat
# 0              NaN          NaN        NaN                  NaN     NaN
# 1              0.0          NaN        NaN                  NaN     NaN

# %% [markdown]
# #### Step 3: Handling Missing Data

# %% [markdown]
# Identify and manage missing values in critical columns such as `Employment`, `JobSat`, and `RemoteWork`. Implement a strategy to fill or drop these values, depending on the significance of the missing data.

# %%
## Write your code here
missing_values = df.isnull().sum().reset_index()
headers = ['column','count']
missing_values.columns = headers
missing_values.sort_values(by='count', ascending=False, inplace=False).reset_index(drop=True)

df = df.dropna(subset=['Employment','JobSat','RemoteWork','YearsCodePro'])

critical_columns = ['Employment','JobSat','RemoteWork','YearsCodePro']
missing_c = df[critical_columns].isnull().sum().reset_index()
missing_c.columns = ['Column', 'MissingValues']
missing_c
# Out:
#          Column  MissingValues
# 0    Employment              0
# 1        JobSat              0
# 2    RemoteWork              0
# 3  YearsCodePro              0

# %%
df['RemoteWork'].unique()
# Out:
# array(['Hybrid (some remote, some in-person)', 'Remote', 'In-person'],
#       dtype=object)

# %% [markdown]
# #### Step 4: Analysis of Experience and Job Satisfaction

# %% [markdown]
# Analyze the relationship between years of professional coding experience (`YearsCodePro`) and job satisfaction (`JobSat`). Summarize `YearsCodePro` and calculate median satisfaction scores based on experience ranges.
#
# - Create experience ranges for `YearsCodePro` (e.g., `0-5`, `5-10`, `10-20`, `>20` years).
#
# - Calculate the median `JobSat` for each range.
#
# - Visualize the relationship using a bar plot or similar visualization.

# %%
## Write your code here
df['YearsCodePro'] = df['YearsCodePro'].replace({
    'Less than 1 year': '0',
    'More than 50 years': '51'
})
df['YearsCodePro'] = df['YearsCodePro'].astype(int)
df['ExperienceRange'] = df['YearsCodePro'].map(lambda x:
    '0-5' if x <= 5 else
    '6-10' if x <= 10 else
    '11-20' if x <= 20 else
    '>20'
)
median_satisfaction = df.groupby('ExperienceRange')['JobSat'].median().reset_index()
print(median_satisfaction)

sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
sns.barplot(x='ExperienceRange', y='JobSat', data=median_satisfaction, palette='viridis',hue='ExperienceRange')

plt.title('Median Job Satisfaction by Professional Coding Experience')
plt.xlabel('Experience Range (Years)')
plt.ylabel('Median Job Satisfaction Score')
plt.ylim(1, 10)
plt.tight_layout()
plt.show()
# Out:
#   ExperienceRange  JobSat
# 0             0-5     7.0
# 1           11-20     8.0
# 2            6-10     7.0
# 3             >20     8.0

# %% [markdown]
# #### Step 5: Visualize Job Satisfaction

# %% [markdown]
# Use a count plot to show the distribution of `JobSat` values. This provides insights into the overall satisfaction levels of respondents.

# %%
## Write your code here
sns.set(style="whitegrid")

# Create the count plot
plt.figure(figsize=(8, 5))
sns.countplot(x='JobSat', data=df, palette='coolwarm', hue = 'JobSat', legend=False)

# Add titles and labels
plt.title('Distribution of Job Satisfaction Levels')
plt.xlabel('Job Satisfaction')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Step 6: Analyzing Remote Work Preferences by Job Role

# %% [markdown]
# Analyze trends in remote work based on job roles. Use the `RemoteWork` and `Employment` columns to explore preferences and examine if specific job roles prefer remote work more than others.
#
# - Use a count plot to show remote work distribution.
#
# - Cross-tabulate remote work preferences by employment type (e.g., full-time, part-time) and job roles.

# %%
## Write your code here
plt.figure(figsize=(8, 5))
sns.countplot(x='RemoteWork', data=df, palette='Set2', hue='RemoteWork')
plt.title('Distribution of Remote Work Preferences')
plt.xlabel('Remote Work Preference')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

remote_employment_ct = pd.crosstab(df['RemoteWork'], df['Employment'], normalize='columns') * 100
remote_employment_ct.round(2)
# Out:
# Employment                            Employed, full-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                44.53
# In-person                                           19.54
# Remote                                              35.93
#
# Employment                            Employed, full-time;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                    39.34
# In-person                                                               12.30
# Remote                                                                  48.36
#
# Employment                            Employed, full-time;Independent contractor, freelancer, or self-employed  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              35.86
# In-person                                                                         10.13
# Remote                                                                            54.01
#
# Employment                            Employed, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              45.61
# In-person                                                                          7.02
# Remote                                                                            47.37
#
# Employment                            Employed, full-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                         100.0
# Remote                                                                              0.0
#
# Employment                            Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              47.73
# In-person                                                                         12.50
# Remote                                                                            39.77
#
# Employment                            Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              42.86
# In-person                                                                         28.57
# Remote                                                                            28.57
#
# Employment                            Employed, full-time;Not employed, and not looking for work  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                         100.0
# Remote                                                                              0.0
#
# Employment                            Employed, full-time;Not employed, but looking for work  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              30.00
# In-person                                                                         26.67
# Remote                                                                            43.33
#
# Employment                            Employed, full-time;Not employed, but looking for work;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                           0.0
# Remote                                                                            100.0
#
# Employment                            Employed, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              57.14
# In-person                                                                          0.00
# Remote                                                                            42.86
#
# Employment                            Employed, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              33.33
# In-person                                                                          0.00
# Remote                                                                            66.67
#
# Employment                            Employed, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                           0.0
# Remote                                                                            100.0
#
# Employment                            Employed, full-time;Not employed, but looking for work;Not employed, and not looking for work;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                           0.0
# Remote                                                                            100.0
#
# Employment                            Employed, full-time;Retired  \
# RemoteWork
# Hybrid (some remote, some in-person)                         50.0
# In-person                                                    25.0
# Remote                                                       25.0
#
# Employment                            Employed, full-time;Student, full-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                   44.24
# In-person                                                              26.70
# Remote                                                                 29.06
#
# Employment                            Employed, full-time;Student, full-time;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              41.67
# In-person                                                                         16.67
# Remote                                                                            41.67
#
# Employment                            Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              50.98
# In-person                                                                          7.84
# Remote                                                                            41.18
#
# Employment                            Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                               60.0
# In-person                                                                          20.0
# Remote                                                                             20.0
#
# Employment                            Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time;Retired  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                           0.0
# Remote                                                                            100.0
#
# Employment                            Employed, full-time;Student, full-time;Not employed, but looking for work  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                           0.0
# Remote                                                                            100.0
#
# Employment                            Employed, full-time;Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              100.0
# In-person                                                                           0.0
# Remote                                                                              0.0
#
# Employment                            Employed, full-time;Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              100.0
# In-person                                                                           0.0
# Remote                                                                              0.0
#
# Employment                            Employed, full-time;Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Student, part-time;Employed, part-time;Retired  \
# RemoteWork
# Hybrid (some remote, some in-person)                                               75.0
# In-person                                                                          25.0
# Remote                                                                              0.0
#
# Employment                            Employed, full-time;Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                          50.0
# Remote                                                                             50.0
#
# Employment                            Employed, full-time;Student, full-time;Not employed, but looking for work;Student, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              100.0
# In-person                                                                           0.0
# Remote                                                                              0.0
#
# Employment                            Employed, full-time;Student, full-time;Student, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              100.0
# In-person                                                                           0.0
# Remote                                                                              0.0
#
# Employment                            Employed, full-time;Student, full-time;Student, part-time;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              100.0
# In-person                                                                           0.0
# Remote                                                                              0.0
#
# Employment                            Employed, full-time;Student, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                   40.78
# In-person                                                              25.82
# Remote                                                                 33.40
#
# Employment                            Employed, full-time;Student, part-time;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                               40.0
# In-person                                                                           0.0
# Remote                                                                             60.0
#
# Employment                            Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                50.75
# In-person                                           18.49
# Remote                                              30.75
#
# Employment                            Employed, part-time;Retired  \
# RemoteWork
# Hybrid (some remote, some in-person)                        100.0
# In-person                                                     0.0
# Remote                                                        0.0
#
# Employment                            Independent contractor, freelancer, or self-employed  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              29.57
# In-person                                                                          4.11
# Remote                                                                            66.32
#
# Employment                            Independent contractor, freelancer, or self-employed;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              47.21
# In-person                                                                          7.61
# Remote                                                                            45.18
#
# Employment                            Independent contractor, freelancer, or self-employed;Employed, part-time;Retired  \
# RemoteWork
# Hybrid (some remote, some in-person)                                               50.0
# In-person                                                                           0.0
# Remote                                                                             50.0
#
# Employment                            Independent contractor, freelancer, or self-employed;Not employed, and not looking for work  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                           0.0
# Remote                                                                            100.0
#
# Employment                            Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                           0.0
# Remote                                                                            100.0
#
# Employment                            Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Retired  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                           0.0
# Remote                                                                            100.0
#
# Employment                            Independent contractor, freelancer, or self-employed;Retired  \
# RemoteWork
# Hybrid (some remote, some in-person)                                               75.0
# In-person                                                                           0.0
# Remote                                                                             25.0
#
# Employment                            Independent contractor, freelancer, or self-employed;Student, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              21.05
# In-person                                                                          0.00
# Remote                                                                            78.95
#
# Employment                            Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              62.07
# In-person                                                                         10.34
# Remote                                                                            27.59
#
# Employment                            Not employed, and not looking for work;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                           0.0
# Remote                                                                            100.0
#
# Employment                            Not employed, but looking for work;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                               20.0
# In-person                                                                          20.0
# Remote                                                                             60.0
#
# Employment                            Not employed, but looking for work;Independent contractor, freelancer, or self-employed  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              16.67
# In-person                                                                          4.76
# Remote                                                                            78.57
#
# Employment                            Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              22.22
# In-person                                                                         11.11
# Remote                                                                            66.67
#
# Employment                            Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                           0.0
# Remote                                                                            100.0
#
# Employment                            Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Retired  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                           0.0
# Remote                                                                            100.0
#
# Employment                            Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Retired  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                           0.0
# Remote                                                                            100.0
#
# Employment                            Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              33.33
# In-person                                                                          0.00
# Remote                                                                            66.67
#
# Employment                            Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                           0.0
# Remote                                                                            100.0
#
# Employment                            Not employed, but looking for work;Student, part-time;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                         100.0
# Remote                                                                              0.0
#
# Employment                            Student, full-time;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                   54.79
# In-person                                                              22.85
# Remote                                                                 22.36
#
# Employment                            Student, full-time;Independent contractor, freelancer, or self-employed  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              39.62
# In-person                                                                         16.98
# Remote                                                                            43.40
#
# Employment                            Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              50.00
# In-person                                                                          7.69
# Remote                                                                            42.31
#
# Employment                            Student, full-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                           0.0
# Remote                                                                            100.0
#
# Employment                            Student, full-time;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              33.33
# In-person                                                                          0.00
# Remote                                                                            66.67
#
# Employment                            Student, full-time;Not employed, but looking for work;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              100.0
# In-person                                                                           0.0
# Remote                                                                              0.0
#
# Employment                            Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed  \
# RemoteWork
# Hybrid (some remote, some in-person)                                              42.86
# In-person                                                                          0.00
# Remote                                                                            57.14
#
# Employment                            Student, full-time;Student, part-time;Employed, part-time  \
# RemoteWork
# Hybrid (some remote, some in-person)                                                0.0
# In-person                                                                           0.0
# Remote                                                                            100.0
#
# Employment                            Student, part-time;Employed, part-time
# RemoteWork
# Hybrid (some remote, some in-person)                                   53.36
# In-person                                                              30.04
# Remote                                                                 16.60

# %% [markdown]
# #### Step 7: Analyzing Programming Language Trends by Region

# %% [markdown]
# Analyze the popularity of programming languages by region. Use the `LanguageHaveWorkedWith` column to investigate which languages are most used in different regions.
#
# - Filter data by country or region.
#
# - Visualize the top programming languages by region with a bar plot or heatmap.

# %%
## Write your code here
df = df.dropna(subset=['Country', 'LanguageHaveWorkedWith'])
df_expanded = df.assign(Language=df['LanguageHaveWorkedWith'].str.split(';')).explode('Language')

lang_counts = df_expanded.groupby(['Country', 'Language']).size().reset_index(name='Count')
lang_counts_sorted = lang_counts.sort_values(['Country', 'Count'], ascending=[True, False])

top_language_by_country = lang_counts_sorted.drop_duplicates(subset='Country', keep='first')
top_language_by_country.reset_index(drop=True)

plt.figure(figsize=(10, 26))
sns.barplot(data=top_language_by_country, y='Country', x='Count', hue='Language', dodge=False)
plt.title('Top Programming Language by Country')
plt.xlabel('Number of Respondents')
plt.ylabel('Country')
plt.tight_layout()
plt.show()

# %%
heatmap_df = top_language_by_country.set_index('Country')[['Language']]

# Map each language to an integer code for visualization
lang_palette = {lang: i for i, lang in enumerate(heatmap_df['Language'].unique())}
heatmap_encoded = heatmap_df['Language'].map(lang_palette).to_frame()

# Create a color palette
colors = sns.color_palette("Set3", n_colors=len(lang_palette))
plt.figure(figsize=(20,10 ))
sns.heatmap(heatmap_encoded.T, 
            cmap=colors, 
            cbar=False, 
            xticklabels=heatmap_encoded.index, 
            yticklabels=['Top Language'])
# Add actual language labels above the heatmap cells
for i, country in enumerate(heatmap_encoded.index):
    plt.text(i + 0.5, 0.5, heatmap_df.loc[country, 'Language'], 
             ha='center', va='center', fontsize=8, rotation=90)

plt.xticks(rotation=90)
plt.title('Top Programming Language by Country')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Step 8: Correlation Between Experience and Satisfaction

# %% [markdown]
# Examine how years of experience (`YearsCodePro`) correlate with job satisfaction (`JobSatPoints_1`). Use a scatter plot to visualize this relationship.

# %%
## Write your code here
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='YearsCodePro', y='JobSatPoints_1', alpha=0.5)

# Optional trend line
sns.regplot(data=df, x='YearsCodePro', y='JobSatPoints_1', scatter=False, color='red')

plt.title('Years of Professional Coding Experience vs Job Satisfaction')
plt.xlabel('Years of Coding Experience (Pro)')
plt.ylabel('Job Satisfaction Score')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Step 9: Educational Background and Employment Type

# %% [markdown]
# Explore how educational background (`EdLevel`) relates to employment type (`Employment`). Use cross-tabulation and visualizations to understand if higher education correlates with specific employment types.

# %%
## Write your code here
df = df.dropna(subset=['EdLevel', 'Employment'])

df_expanded = df.assign(EmplmtType=df['Employment'].str.split(';')).explode('EmplmtType')

emplmt_counts = df_expanded.groupby(['EdLevel', 'EmplmtType']).size().reset_index(name='Count')

emplmt_counts_sorted = emplmt_counts.sort_values(['EdLevel', 'Count'], ascending=[True, False])

top_emplmt_by_country = emplmt_counts_sorted.drop_duplicates(subset='EdLevel', keep='first')
top_emplmt_by_country.reset_index(drop=True)

edu_emp_ct = pd.crosstab(df_expanded['EdLevel'], df_expanded['EmplmtType'],normalize='index') * 100

edu_emp_ct.plot(kind='bar', stacked=True, figsize=(12, 12), colormap='Set3')

plt.title('Employment Type by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Proportion of Respondents')
plt.legend(title='Employment Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(edu_emp_ct, annot=True, cmap='YlGnBu', fmt='.2f')

plt.title('Heatmap of Employment Type by Education Level')
plt.xlabel('Employment Type')
plt.ylabel('Education Level')
plt.tight_layout()
plt.show()
edu_emp_ct
# Out:
# EmplmtType                                          Employed, full-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                           74.223895
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                  78.781991
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)               79.506519
# Primary/elementary school                                     62.285714
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                81.728232
# Secondary school (e.g. American high school, Ge...            55.335366
# Some college/university study without earning a...            67.425527
# Something else                                                70.170455
#
# EmplmtType                                          Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                            5.362183
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                   4.535710
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                4.094386
# Primary/elementary school                                     10.285714
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                 4.221636
# Secondary school (e.g. American high school, Ge...            13.414634
# Some college/university study without earning a...             7.023492
# Something else                                                 6.818182
#
# EmplmtType                                          Independent contractor, freelancer, or self-employed  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                         12.135466
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                11.188530
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                             12.800345
# Primary/elementary school                                                                   16.000000
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                              11.411609
# Secondary school (e.g. American high school, Ge...                                          14.989837
# Some college/university study without earning a...                                          15.596997
# Something else                                                                              13.920455
#
# EmplmtType                                          Not employed, and not looking for work  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                               0.094073
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                      0.026799
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                   0.064648
# Primary/elementary school                                                         0.571429
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                    0.065963
# Secondary school (e.g. American high school, Ge...                                0.000000
# Some college/university study without earning a...                                0.096876
# Something else                                                                    0.284091
#
# EmplmtType                                          Not employed, but looking for work  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                           0.188147
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                  0.401983
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                               0.323241
# Primary/elementary school                                                     0.571429
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                0.263852
# Secondary school (e.g. American high school, Ge...                            0.813008
# Some college/university study without earning a...                            0.314846
# Something else                                                                0.852273
#
# EmplmtType                                           Retired  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                 0.094073
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)        0.020099
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)     0.032324
# Primary/elementary school                           0.571429
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)      0.329815
# Secondary school (e.g. American high school, Ge...  0.000000
# Some college/university study without earning a...  0.145314
# Something else                                      0.568182
#
# EmplmtType                                          Student, full-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                           3.480715
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                  2.505695
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)               1.454585
# Primary/elementary school                                     6.857143
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                0.857520
# Secondary school (e.g. American high school, Ge...           10.670732
# Some college/university study without earning a...            4.746912
# Something else                                                2.840909
#
# EmplmtType                                          Student, part-time
# EdLevel
# Associate degree (A.A., A.S., etc.)                           4.421449
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                  2.539193
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)               1.723952
# Primary/elementary school                                     2.857143
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                1.121372
# Secondary school (e.g. American high school, Ge...            4.776423
# Some college/university study without earning a...            4.650036
# Something else                                                4.545455

# %% [markdown]
# #### Step 10: Save the Cleaned and Analyzed Dataset

# %% [markdown]
# After your analysis, save the modified dataset for further use or sharing.

# %%
## Write your code here
df.to_csv('cleaned_survey_data.csv', index=False)

# %% [markdown]
# <h2>Summary</h2>

# %% [markdown]
# In this revised lab, you:
#
# - Loaded and explored the structure of the dataset.
#
# - Handled missing data effectively.
#
# - Analyzed key variables, including working hours, job satisfaction, and remote work trends.
#
# - Investigated programming language usage by region and examined the relationship between experience and satisfaction.
#
# - Used cross-tabulation to understand educational background and employment type.

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
